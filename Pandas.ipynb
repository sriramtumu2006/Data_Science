# %% [markdown]
# <a href="https://colab.research.google.com/github/sriramtumu2006/Data_Science/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
a=[1,2,3,4,5]
s=pd.Series(a,index=['1st','2nd','3rd','4th','5th'])
s
# Out:
# 1st    1
# 2nd    2
# 3rd    3
# 4th    4
# 5th    5
# dtype: int64

# %%
a={"A":10,"B":20,"C":30}
b=pd.Series(a)
b
# Out:
# A    10
# B    20
# C    30
# dtype: int64

# %% [markdown]
# Using **Pandas Series**, perform the following:
#
# ✅ Create a Series named `scores` using the dictionary `student_scores`.
#
# ✅ Print the marks scored by **"Charlie"** and **"Eva"**.
#
# ✅ Add **5 bonus marks** to all students and print the updated Series.
#
# ✅ Display only the students who scored **above 90** after the bonus.
#
# ✅ Calculate and print the **average marks** of the class (after the bonus).

# %%
student_scores={'Alice':85,'Bob':92,'Charlie':78,'David':95,'Eva':88}
scores=pd.Series(student_scores)
print("Charlie's Score : ",scores['Charlie'])
print("Eva's Score : ",scores['Eva'])
scores=scores+5
print("Scores :\n",scores)
print("Students who scored > 90 :\n",scores[scores>90])
print("Average Marks : ",scores.mean())
# Out:
# Charlie's Score :  78
# Eva's Score :  88
# Scores :
#  Alice       90
# Bob         97
# Charlie     83
# David      100
# Eva         93
# dtype: int64
# Students who scored > 90 :
#  Bob       97
# David    100
# Eva       93
# dtype: int64
# Average Marks :  92.6

# %%
import pandas as pd
import numpy as np
a=np.array([[20,90],[21,85],[22,89],[23,91]])
s=pd.DataFrame(a,index=['Ram','Shyam','Varun','Rahul'],columns=['Age','Marks'])
print("DataFrame : \n",s)
print("Values : \n",s.values)
print("Index : ",s.index)
print("Columns : ",s.columns)
# Out:
# DataFrame :
#         Age  Marks
# Ram     20     90
# Shyam   21     85
# Varun   22     89
# Rahul   23     91
# Values :
#  [[20 90]
#  [21 85]
#  [22 89]
#  [23 91]]
# Index :  Index(['Ram', 'Shyam', 'Varun', 'Rahul'], dtype='object')
# Columns :  Index(['Age', 'Marks'], dtype='object')

# %%
dic={'name':{'SR':'Sriram','RO':'Rohit','VA':'Varun'},
     'age':{'SR':20,'RO':21,'VA':22},
     'marks':{'SR':84,'RO':85,'VA':91}}
s=pd.DataFrame(dic)
s
# Out:
#       name  age  marks
# SR  Sriram   20     84
# RO   Rohit   21     85
# VA   Varun   22     91

# %%
d={'name':['Sriram','Rohith','Varun'],
   'age':[20,21,22],
   'marks':[84,85,91]}
s=pd.DataFrame(d,index=['SR','RO','VA'])
print("s : \n",s)
print("Type(s.values) : ",type(s.values))
print("Dimensions : ",s.ndim)
print("Shape : ",s.shape)
# Out:
# s :
#        name  age  marks
# SR  Sriram   20     84
# RO  Rohith   21     85
# VA   Varun   22     91
# Type(s.values) :  <class 'numpy.ndarray'>
# Dimensions :  2
# Shape :  (3, 3)

# %%
s1=pd.Series(['Sriram','Rohith','Varun'],index=['SR','RO','VA'])
s2=pd.Series([20,21,22],index=['SR','RO','VA'])
s3=pd.Series([84,85,91],index=['SR','RO','VA'])
dic={'name':s1,'age':s2,'marks':s3}
s=pd.DataFrame(dic)
s
# Out:
#       name  age  marks
# SR  Sriram   20     84
# RO  Rohith   21     85
# VA   Varun   22     91

# %% [markdown]
# You are given three Series representing student data:
#
# Names of students
#
# Their ages
#
# Their marks
#
# These series are combined into a DataFrame as shown earlier.
#
# ### 🎯 Your Task:
# Using the existing DataFrame, perform the following operations:
#
# ✅ Print the details (name, age, marks) of the student who scored the highest marks.
#
# ✅ Add a new student "Tharushi" with age 23 and marks 88 using the index "Th".
#
# ✅ Display the details of students who are 25 years old or older.
#
# ✅ Increase the marks of students below 80 by 10 bonus points.
#
# ✅ Calculate and print the average marks of all students after the bonus.

# %%
s1=pd.Series(['Sriram','Rohith','Varun'],index=[1,2,3])
s2=pd.Series([26,21,22],index=[1,2,3])
s3=pd.Series([84,85,91],index=[1,2,3])
dic={'name':s1,'age':s2,'marks':s3}
s=pd.DataFrame(dic)
print("Student Who Scored Highest Marks : \n",s[s['marks']==max(s['marks'])])#s.loc[s['marks'].idxmax()]
s.loc[4]=['Tharushi',23,88]
print("Students Who Are 25 Years Old or Older : \n",s[s['age']>=25])
for i in s['marks']:
  if i<80:
    i+=10
print("Average Marks : ",s['marks'].mean())
# Out:
# Student Who Scored Highest Marks :
#      name  age  marks
# 3  Varun   22     91
# Students Who Are 25 Years Old or Older :
#       name  age  marks
# 1  Sriram   26     84
# Average Marks :  87.0

# %%
from google.colab import drive
drive.mount('/content/drive')
df=pd.read_csv('/content/drive/MyDrive/data.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'],format='mixed')
print(df.to_string())
df.dropna(subset=['Date'],inplace=True)
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7        450 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# 18        45 2020-12-18     90       112    304.68
# 19        60 2020-12-19    103       123    323.00
# 20        45 2020-12-20     97       125    243.00
# 21        60 2020-12-21    108       131    364.20
# 23        60 2020-12-23    130       101    300.00
# 24        45 2020-12-24    105       132    246.00
# 25        60 2020-12-25    102       126    334.50
# 26        60 2020-12-26    100       120    250.00
# 27        60 2020-12-27     92       118    241.00
# 28        60 2020-12-28    103       132    304.68
# 29        60 2020-12-29    100       132    280.00
# 30        60 2020-12-30    102       129    380.30
# 31        60 2020-12-31     92       115    243.00
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7        450 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# 18        45 2020-12-18     90       112    304.68
# 19        60 2020-12-19    103       123    323.00
# 20        45 2020-12-20     97       125    243.00
# 21        60 2020-12-21    108       131    364.20
# 23        60 2020-12-23    130       101    300.00
# 24        45 2020-12-24    105       132    246.00
# 25        60 2020-12-25    102       126    334.50
# 26        60 2020-12-26    100       120    250.00
# 27        60 2020-12-27     92       118    241.00
# 28        60 2020-12-28    103       132    304.68
# 29        60 2020-12-29    100       132    280.00
# 30        60 2020-12-30    102       129    380.30
# 31        60 2020-12-31     92       115    243.00

# %%
df.loc[7,'Duration']=45
print(df.to_string())
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# 18        45 2020-12-18     90       112    304.68
# 19        60 2020-12-19    103       123    323.00
# 20        45 2020-12-20     97       125    243.00
# 21        60 2020-12-21    108       131    364.20
# 23        60 2020-12-23    130       101    300.00
# 24        45 2020-12-24    105       132    246.00
# 25        60 2020-12-25    102       126    334.50
# 26        60 2020-12-26    100       120    250.00
# 27        60 2020-12-27     92       118    241.00
# 28        60 2020-12-28    103       132    304.68
# 29        60 2020-12-29    100       132    280.00
# 30        60 2020-12-30    102       129    380.30
# 31        60 2020-12-31     92       115    243.00

# %%
for x in df.index:
  if df.loc[x,'Duration']>120:
    df.loc[x,'Duration']=120
df
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 12        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# 18        45 2020-12-18     90       112    304.68
# 19        60 2020-12-19    103       123    323.00
# 20        45 2020-12-20     97       125    243.00
# 21        60 2020-12-21    108       131    364.20
# 23        60 2020-12-23    130       101    300.00
# 24        45 2020-12-24    105       132    246.00
# 25        60 2020-12-25    102       126    334.50
# 26        60 2020-12-26    100       120    250.00
# 27        60 2020-12-27     92       118    241.00
# 28        60 2020-12-28    103       132    304.68
# 29        60 2020-12-29    100       132    280.00
# 30        60 2020-12-30    102       129    380.30
# 31        60 2020-12-31     92       115    243.00

# %%
print(df.duplicated())
df.drop_duplicates(inplace=True)
df
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool
#     Duration       Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01    110       130    409.10
# 1         60 2020-12-02    117       145    479.00
# 2         60 2020-12-03    103       135    340.00
# 3         45 2020-12-04    109       175    282.40
# 4         45 2020-12-05    117       148    406.00
# 5         60 2020-12-06    102       127    300.00
# 6         60 2020-12-07    110       136    374.00
# 7         45 2020-12-08    104       134    253.30
# 8         30 2020-12-09    109       133    195.10
# 9         60 2020-12-10     98       124    269.00
# 10        60 2020-12-11    103       147    329.30
# 11        60 2020-12-12    100       120    250.70
# 13        60 2020-12-13    106       128    345.30
# 14        60 2020-12-14    104       132    379.30
# 15        60 2020-12-15     98       123    275.00
# 16        60 2020-12-16     98       120    215.20
# 17        60 2020-12-17    100       120    300.00
# 18        45 2020-12-18     90       112    304.68
# 19        60 2020-12-19    103       123    323.00
# 20        45 2020-12-20     97       125    243.00
# 21        60 2020-12-21    108       131    364.20
# 23        60 2020-12-23    130       101    300.00
# 24        45 2020-12-24    105       132    246.00
# 25        60 2020-12-25    102       126    334.50
# 26        60 2020-12-26    100       120    250.00
# 27        60 2020-12-27     92       118    241.00
# 28        60 2020-12-28    103       132    304.68
# 29        60 2020-12-29    100       132    280.00
# 30        60 2020-12-30    102       129    380.30
# 31        60 2020-12-31     92       115    243.00

# %%
high_pulse=df[df['Pulse']>110]
print(high_pulse)
print()
sorted_df=df.sort_values(by='Calories',ascending=False)
print(sorted_df)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories  PulseRange
# 1         60 2020-12-02    117       145     479.0  (110, 120]
# 4         45 2020-12-05    117       148     406.0  (110, 120]
# 23        60 2020-12-23    130       101     300.0  (120, 130]
#
#     Duration       Date  Pulse  Maxpulse  Calories      PulseRange
# 1         60 2020-12-02    117       145    479.00  (110.0, 120.0]
# 0         60 2020-12-01    110       130    409.10  (100.0, 110.0]
# 4         45 2020-12-05    117       148    406.00  (110.0, 120.0]
# 30        60 2020-12-30    102       129    380.30  (100.0, 110.0]
# 14        60 2020-12-14    104       132    379.30  (100.0, 110.0]
# 6         60 2020-12-07    110       136    374.00  (100.0, 110.0]
# 21        60 2020-12-21    108       131    364.20  (100.0, 110.0]
# 13        60 2020-12-13    106       128    345.30  (100.0, 110.0]
# 2         60 2020-12-03    103       135    340.00  (100.0, 110.0]
# 25        60 2020-12-25    102       126    334.50  (100.0, 110.0]
# 10        60 2020-12-11    103       147    329.30  (100.0, 110.0]
# 19        60 2020-12-19    103       123    323.00  (100.0, 110.0]
# 28        60 2020-12-28    103       132    304.68  (100.0, 110.0]
# 18        45 2020-12-18     90       112    304.68             NaN
# 23        60 2020-12-23    130       101    300.00  (120.0, 130.0]
# 5         60 2020-12-06    102       127    300.00  (100.0, 110.0]
# 17        60 2020-12-17    100       120    300.00             NaN
# 3         45 2020-12-04    109       175    282.40  (100.0, 110.0]
# 29        60 2020-12-29    100       132    280.00             NaN
# 15        60 2020-12-15     98       123    275.00             NaN
# 9         60 2020-12-10     98       124    269.00             NaN
# 7         45 2020-12-08    104       134    253.30  (100.0, 110.0]
# 11        60 2020-12-12    100       120    250.70             NaN
# 26        60 2020-12-26    100       120    250.00             NaN
# 24        45 2020-12-24    105       132    246.00  (100.0, 110.0]
# 31        60 2020-12-31     92       115    243.00             NaN
# 20        45 2020-12-20     97       125    243.00             NaN
# 27        60 2020-12-27     92       118    241.00             NaN
# 16        60 2020-12-16     98       120    215.20             NaN
# 8         30 2020-12-09    109       133    195.10  (100.0, 110.0]

# %%
trainer_df = pd.DataFrame({
    'Date': ['2020/12/01', '2020/12/02', '2020/12/03'],
    'Trainer': ['Alex', 'Jordan', 'Taylor']
})
trainer_df['Date'] = pd.to_datetime(trainer_df['Date'])
merged_df = pd.merge(df, trainer_df, on='Date')
print(merged_df)
# Out:
#    Duration       Date  Pulse  Max_Pulse  Calories  PulseRange Trainer
# 0        60 2020-12-01    110        130     409.1  (100, 110]    Alex
# 1        60 2020-12-02    117        145     479.0  (110, 120]  Jordan
# 2        60 2020-12-03    103        135     340.0  (100, 110]  Taylor

# %%
avg_calories_by_duration = df.groupby('Duration')['Calories'].mean()
print(avg_calories_by_duration)
df['PulseRange'] = pd.cut(df['Pulse'], bins=[100, 110, 120, 130, 140, 150, 180])
grouped_stats = df.groupby('PulseRange', observed=False).agg({
    'Calories': 'mean',
    'Maxpulse': 'max'
})
print(grouped_stats)
# Out:
# Duration
# 30    195.100000
# 45    289.230000
# 60    316.807826
# Name: Calories, dtype: float64
#             Calories  Maxpulse
# PulseRange
# (100, 110]    322.53     175.0
# (110, 120]    442.50     148.0
# (120, 130]    300.00     101.0
# (130, 140]       NaN       NaN
# (140, 150]       NaN       NaN
# (150, 180]       NaN       NaN

# %%
print(df.corr(numeric_only=True))
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.083417 -0.296585  0.338213
# Pulse    -0.083417  1.000000  0.261426  0.478723
# Maxpulse -0.296585  0.261426  1.000000  0.329600
# Calories  0.338213  0.478723  0.329600  1.000000

# %%
df.rename(columns={'Maxpulse':'Max_Pulse'},inplace=True)

# %%
df.describe()
# Out:
#         Duration                 Date       Pulse   Max_Pulse    Calories
# count  30.000000                   30   30.000000   30.000000   30.000000
# mean   56.000000  2020-12-15 19:12:00  103.733333  129.100000  307.235333
# min    30.000000  2020-12-01 00:00:00   90.000000  101.000000  195.100000
# 25%    60.000000  2020-12-08 06:00:00  100.000000  120.750000  251.350000
# 50%    60.000000  2020-12-15 12:00:00  103.000000  128.500000  300.000000
# 75%    60.000000  2020-12-23 18:00:00  107.500000  132.750000  343.975000
# max    60.000000  2020-12-31 00:00:00  130.000000  175.000000  479.000000
# std     7.812457                  NaN    8.042702   13.215325   65.050207

# %%
df.value_counts()
# Out:
# Duration  Date        Pulse  Max_Pulse  Calories  PulseRange
# 30        2020-12-09  109    133        195.10    (100, 110]    1
# 45        2020-12-04  109    175        282.40    (100, 110]    1
#           2020-12-05  117    148        406.00    (110, 120]    1
#           2020-12-08  104    134        253.30    (100, 110]    1
#           2020-12-24  105    132        246.00    (100, 110]    1
# 60        2020-12-01  110    130        409.10    (100, 110]    1
#           2020-12-02  117    145        479.00    (110, 120]    1
#           2020-12-03  103    135        340.00    (100, 110]    1
#           2020-12-06  102    127        300.00    (100, 110]    1
#           2020-12-07  110    136        374.00    (100, 110]    1
#           2020-12-11  103    147        329.30    (100, 110]    1
#           2020-12-13  106    128        345.30    (100, 110]    1
#           2020-12-14  104    132        379.30    (100, 110]    1
#           2020-12-19  103    123        323.00    (100, 110]    1
#           2020-12-21  108    131        364.20    (100, 110]    1
#           2020-12-23  130    101        300.00    (120, 130]    1
#           2020-12-25  102    126        334.50    (100, 110]    1
#           2020-12-28  103    132        304.68    (100, 110]    1
#           2020-12-30  102    129        380.30    (100, 110]    1
# Name: count, dtype: int64

# %%
print(df['Pulse'].value_counts())
# Out:
# Pulse
# 103    4
# 100    4
# 98     3
# 102    3
# 117    2
# 109    2
# 110    2
# 104    2
# 92     2
# 90     1
# 106    1
# 97     1
# 108    1
# 130    1
# 105    1
# Name: count, dtype: int64

# %%
df.query('Pulse>110 and Calories<400')
df[df['Calories'].between(200,500)]
# Out:
#     Duration       Date  Pulse  Max_Pulse  Calories      PulseRange
# 0         60 2020-12-01    110        130    409.10  (100.0, 110.0]
# 1         60 2020-12-02    117        145    479.00  (110.0, 120.0]
# 2         60 2020-12-03    103        135    340.00  (100.0, 110.0]
# 3         45 2020-12-04    109        175    282.40  (100.0, 110.0]
# 4         45 2020-12-05    117        148    406.00  (110.0, 120.0]
# 5         60 2020-12-06    102        127    300.00  (100.0, 110.0]
# 6         60 2020-12-07    110        136    374.00  (100.0, 110.0]
# 7         45 2020-12-08    104        134    253.30  (100.0, 110.0]
# 9         60 2020-12-10     98        124    269.00             NaN
# 10        60 2020-12-11    103        147    329.30  (100.0, 110.0]
# 11        60 2020-12-12    100        120    250.70             NaN
# 13        60 2020-12-13    106        128    345.30  (100.0, 110.0]
# 14        60 2020-12-14    104        132    379.30  (100.0, 110.0]
# 15        60 2020-12-15     98        123    275.00             NaN
# 16        60 2020-12-16     98        120    215.20             NaN
# 17        60 2020-12-17    100        120    300.00             NaN
# 18        45 2020-12-18     90        112    304.68             NaN
# 19        60 2020-12-19    103        123    323.00  (100.0, 110.0]
# 20        45 2020-12-20     97        125    243.00             NaN
# 21        60 2020-12-21    108        131    364.20  (100.0, 110.0]
# 23        60 2020-12-23    130        101    300.00  (120.0, 130.0]
# 24        45 2020-12-24    105        132    246.00  (100.0, 110.0]
# 25        60 2020-12-25    102        126    334.50  (100.0, 110.0]
# 26        60 2020-12-26    100        120    250.00             NaN
# 27        60 2020-12-27     92        118    241.00             NaN
# 28        60 2020-12-28    103        132    304.68  (100.0, 110.0]
# 29        60 2020-12-29    100        132    280.00             NaN
# 30        60 2020-12-30    102        129    380.30  (100.0, 110.0]
# 31        60 2020-12-31     92        115    243.00             NaN

# %%
merged_df['Trainer']=merged_df['Trainer'].str.title()
merged_df[merged_df['Trainer'].str.contains('Alex')]
# Out:
#    Duration       Date  Pulse  Max_Pulse  Calories  PulseRange Trainer
# 0        60 2020-12-01    110        130     409.1  (100, 110]    Alex

# %% [markdown]
# “E-Commerce Transaction Analytics” (Using Online Retail Dataset)
# 🎯 Scenario / Story
# You are a data analyst at ShopWave, an e-commerce platform in the UK. ShopWave logs every transaction (order) made in their store. Each record has:
#
# Invoice number
#
# Stock code / product ID
#
# Description
#
# Quantity
#
# Invoice date
#
# Unit price
#
# Customer ID
#
# Country
#
# Your manager wants you to clean the data, fix inconsistencies, derive business metrics, and explore relationships. The cleaned data should enable deeper dashboards later.
#
#
# Tasks & Steps
# Below is a full pipeline of tasks that students should perform. Each task corresponds to one or more of the functions/techniques you already taught.
#
# Load & Inspect
#
# Read the CSV (e.g. OnlineRetail.csv)
#
# Display head(), tail(), info(), shape
#
# Check dtypes
#
# Missing Data Handling
#
# Use isnull().sum() to find missing values (e.g. some Description or Customer ID missing)
#
# Drop rows that have missing Customer ID (because you can’t tie to a customer)
#
# Fill missing Description or other columns using a placeholder (e.g. "Unknown")
#
# Date Parsing / Format Correction
# The InvoiceDate column might be string. Convert using pd.to_datetime(..., format='mixed')
#
# Drop records where parsing failed (if any)
# Detect & Fix Bad or Outlier Data
#
# Some transactions might have negative quantity (returns) — detect those and decide whether to treat as returns or drop
#
# Some unit prices might be zero or negative — fix/clean these (e.g. drop or adjust)
#
# Duplicates
# Use duplicated() to find duplicated invoice-item entries
# Drop duplicates
